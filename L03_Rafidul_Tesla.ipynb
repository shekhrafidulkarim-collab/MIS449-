# %%
#Import necessary libraries
import yfinance as yf
import pandas as pd
import numpy as np
from datetime import datetime
from sklearn.linear_model import LinearRegression

# %%
stock_data = yf.download("TSLA", start="2020-01-01", end="2026-01-01")
stock_data.head()
# Out:
# /tmp/ipykernel_668/1328133471.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   stock_data = yf.download("TSLA", start="2020-01-01", end="2026-01-01")
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           TSLA       TSLA       TSLA       TSLA       TSLA
# Date
# 2020-01-02  28.684000  28.713333  28.114000  28.299999  142981500
# 2020-01-03  29.534000  30.266666  29.128000  29.366667  266677500
# 2020-01-06  30.102667  30.104000  29.333332  29.364668  151995000
# 2020-01-07  31.270666  31.441999  30.224001  30.760000  268231500
# 2020-01-08  32.809334  33.232666  31.215334  31.580000  467164500

# %%
#reset stock index
data = stock_data.reset_index()

# %%
#Convert Date Column
data['Date'] = pd.to_datetime(data['Date'])

data['Date_Ordinal'] = data['Date'].map(datetime.toordinal)

# %%
#Feature & Target
X = data[['Date_Ordinal']]
y = data['Close']

# %%
#model training data
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
#Input
predict_date = input("Enter date to predict (YYYY-MM-DD): ")

predict_date = datetime.strptime(predict_date, "%Y-%m-%d")
predict_ordinal = predict_date.toordinal()

predicted_price = model.predict([[predict_ordinal]])

print("Predicted Closing Price:", predicted_price[0])
# Out:
# Enter date to predict (YYYY-MM-DD): 2026-01-20
# Predicted Closing Price: [344.44114734]
