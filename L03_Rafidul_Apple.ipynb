# %%
#Import necessary libraries
import yfinance as yf
import pandas as pd
import numpy as np
from datetime import datetime
from sklearn.linear_model import LinearRegression

# %%
stock_data = yf.download("AAPL", start="2020-01-01", end="2026-01-01")
stock_data.head()
# Out:
# /tmp/ipykernel_135/180047259.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   stock_data = yf.download("AAPL", start="2020-01-01", end="2026-01-01")
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2020-01-02  72.400528  72.460791  71.156689  71.409793  135480400
# 2020-01-03  71.696632  72.455950  71.472454  71.629138  146322800
# 2020-01-06  72.267914  72.306483  70.568488  70.819186  118387200
# 2020-01-07  71.928078  72.533118  71.708718  72.277601  108872000
# 2020-01-08  73.085114  73.386431  71.631559  71.631559  132079200

# %%
#reset stock index
data = stock_data.reset_index()

# %%
#Convert Date Column
data['Date'] = pd.to_datetime(data['Date'])

data['Date_Ordinal'] = data['Date'].map(datetime.toordinal)

# %%
#Feature & Target
X = data[['Date_Ordinal']]
y = data['Close']

# %%
#model training data
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
#Input
predict_date = input("Enter date to predict (YYYY-MM-DD): ")

predict_date = datetime.strptime(predict_date, "%Y-%m-%d")
predict_ordinal = predict_date.toordinal()

predicted_price = model.predict([[predict_ordinal]])

print("Predicted Closing Price:", predicted_price[0])
# Out:
# Enter date to predict (YYYY-MM-DD): 2026-01-20
# Predicted Closing Price: [246.53427123]
